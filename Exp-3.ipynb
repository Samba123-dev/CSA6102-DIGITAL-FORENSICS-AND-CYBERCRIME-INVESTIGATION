# %% [markdown]
# <a href="https://colab.research.google.com/github/Samba123-dev/CSA6102-DIGITAL-FORENSICS-AND-CYBERCRIME-INVESTIGATION/blob/main/Exp-3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
sender = input("Sender: ")
subject = input("Subject: ")
body = input("Body: ")

score = 0


if "@" not in sender:
    score += 1

if "urgent" in subject.lower() or "verify" in subject.lower():
    score += 1

if "click here" in body.lower() or "password" in body.lower():
    score += 1

if score >= 2:
    print("Phishing Email Detected")
else:
    print("Email Appears Safe")
# Out:
# Sender: fakebank
# Subject: urgent verify account
# Body: cliclk here to update password Phishing Email Detected
# Phishing Email Detected
