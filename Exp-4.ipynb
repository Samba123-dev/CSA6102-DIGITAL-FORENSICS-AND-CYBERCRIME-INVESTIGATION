# %% [markdown]
# <a href="https://colab.research.google.com/github/Samba123-dev/CSA6102-DIGITAL-FORENSICS-AND-CYBERCRIME-INVESTIGATION/blob/main/Exp-4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import socket

print("===================================")
print("      DNS Lookup Tool (OSINT)")
print("===================================")

# Get domain name from user
domain = input("Enter the domain name (e.g., google.com): ")

try:
    # Perform DNS lookup
    ip_address = socket.gethostbyname(domain)

    print("\nDNS Lookup Successful!")
    print("----------------------------")
    print("Domain Name :", domain)
    print("IP Address  :", ip_address)

except socket.gaierror:
    print("\nError: Unable to resolve the domain name.")
# Out:
# ...
#       DNS Lookup Tool (OSINT)
# ...
# Enter the domain name (e.g., google.com): openai.com
#
# DNS Lookup Successful!
# ----------------------------
# Domain Name : openai.com
# IP Address  : 172.64.154.211
