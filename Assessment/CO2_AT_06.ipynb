# %% [markdown]
# <a href="https://colab.research.google.com/github/Samba123-dev/CSA6102-DIGITAL-FORENSICS-AND-CYBERCRIME-INVESTIGATION/blob/main/Assessment/CO2_AT_06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re
def is_suspicious(url):
    ip_pattern = r'\d+\.\d+\.\d+\.\d+'
    suspicious_words = ('verify', 'update', 'secure', 'login')
    if re.search(ip_pattern, url):
        return True
    for word in suspicious_words:
        if word in url:
            return True
    return False
urls = ['http://192.168.1.10/verify-account', 'https://mybank.com/login']
for u in urls:
    print(u, '->', is_suspicious(u))
# Out:
# http://192.168.1.10/verify-account -> True
# https://mybank.com/login -> True
