# %% [markdown]
# <a href="https://colab.research.google.com/github/Samba123-dev/CSA6102-DIGITAL-FORENSICS-AND-CYBERCRIME-INVESTIGATION/blob/main/Assessment/CO2_AT_08.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import hashlib
import os

def compute_hash(filepath):
    hasher = hashlib.sha256()

    with open(filepath, 'rb') as f:
        while chunk := f.read(4096):
            hasher.update(chunk)

    return hasher.hexdigest()

def verify_integrity(filepath):
    if not os.path.exists(filepath):
        print("File not found:", filepath)
        return

    hash_at_collection = compute_hash(filepath)
    hash_before_analysis = compute_hash(filepath)

    if hash_at_collection == hash_before_analysis:
        print("Match: Evidence integrity verified")
    else:
        print("Mismatch: Evidence may be compromised")

verify_integrity('evidence_image.dd')
# Out:
# File not found: evidence_image.dd
