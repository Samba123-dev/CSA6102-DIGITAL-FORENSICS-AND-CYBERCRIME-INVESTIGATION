# %% [markdown]
# <a href="https://colab.research.google.com/github/Samba123-dev/CSA6102-DIGITAL-FORENSICS-AND-CYBERCRIME-INVESTIGATION/blob/main/Exp_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Welcome to Colab!

# %%
import os
import time
from datetime import datetime

# File name
filename = "metadata_demo.txt"

# Create the file if it does not exist
with open(filename, "w") as file:
    file.write("Initial content.\n")

    print("=== BEFORE MODIFICATION ===")
    print("Created Time     :", datetime.fromtimestamp(os.path.getctime(filename)))
    print("Modified Time    :", datetime.fromtimestamp(os.path.getmtime(filename)))
    print("Last Access Time :", datetime.fromtimestamp(os.path.getatime(filename)))

    # Wait for a few seconds
    time.sleep(5)

    # Modify the file
    with open(filename, "a") as file:
        file.write("This line was added later.\n")

        print("\nFile has been modified...\n")

        print("=== AFTER MODIFICATION ===")
        print("Created Time     :", datetime.fromtimestamp(os.path.getctime(filename)))
        print("Modified Time    :", datetime.fromtimestamp(os.path.getmtime(filename)))
        print("Last Access Time :", datetime.fromtimestamp(os.path.getatime(filename)))

        print("\nObservation:")
        print("The modification timestamp has changed after editing the file.")
        print("This metadata acts as digital evidence, demonstrating Locard's Exchange Principle.")
# Out:
# === BEFORE MODIFICATION ===
# Created Time     : 2026-07-24 13:52:51.637510
# Modified Time    : 2026-07-24 13:52:51.637510
# Last Access Time : 2026-07-24 13:52:51.637510
#
# File has been modified...
#
# === AFTER MODIFICATION ===
# Created Time     : 2026-07-24 13:52:51.637510
# Modified Time    : 2026-07-24 13:52:51.637510
# Last Access Time : 2026-07-24 13:52:51.972513
#
# Observation:
# The modification timestamp has changed after editing the file.
# This metadata acts as digital evidence, demonstrating Locard's Exchange Principle.

# %%
import os
import time
from datetime import datetime

# File name
filename = "metadata_demo.txt"

# Create the file if it does not exist
with open(filename, "w") as file:
    file.write("Initial content.\n")

    print("=== BEFORE MODIFICATION ===")
    print("Created Time     :", datetime.fromtimestamp(os.path.getctime(filename)))
    print("Modified Time    :", datetime.fromtimestamp(os.path.getmtime(filename)))
    print("Last Access Time :", datetime.fromtimestamp(os.path.getatime(filename)))

    # Wait for a few seconds
    time.sleep(5)

    # Modify the file
    with open(filename, "a") as file:
        file.write("This line was added later.\n")

        print("\nFile has been modified...\n")

        print("=== AFTER MODIFICATION ===")
        print("Created Time     :", datetime.fromtimestamp(os.path.getctime(filename)))
        print("Modified Time    :", datetime.fromtimestamp(os.path.getmtime(filename)))
        print("Last Access Time :", datetime.fromtimestamp(os.path.getatime(filename)))

        print("\nObservation:")
        print("The modification timestamp has changed after editing the file.")
        print("This metadata acts as digital evidence, demonstrating Locard's Exchange Principle.")
# Out:
# === BEFORE MODIFICATION ===
# Created Time     : 2026-07-24 13:49:40.360760
# Modified Time    : 2026-07-24 13:49:40.360760
# Last Access Time : 2026-07-24 13:49:40.360760
#
# File has been modified...
#
# === AFTER MODIFICATION ===
# Created Time     : 2026-07-24 13:49:40.360760
# Modified Time    : 2026-07-24 13:49:40.360760
# Last Access Time : 2026-07-24 13:49:44.964755
#
# Observation:
# The modification timestamp has changed after editing the file.
# This metadata acts as digital evidence, demonstrating Locard's Exchange Principle.
